# %%
import seaborn as sns
from sklearn.datasets import make_blobs

# %%
from sklearn.cluster import Kmeans

# %%
X, y = make_blobs(
    n_samples = 1500,
    n_features = 9,
    centers = 4,
    random_state = 42
)
